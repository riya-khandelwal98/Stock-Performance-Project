# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

from sklearn.model_selection import train_test_split
from sklearn.impute import SimpleImputer
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.ensemble import RandomForestClassifier
from sklearn.experimental import enable_iterative_imputer  
from sklearn.impute import IterativeImputer
from sklearn.linear_model import BayesianRidge
from sklearn.base import BaseEstimator, TransformerMixin

# %%
df = pd.read_csv('2018_Financial_Data.csv')
df['Class'] = df['2019 PRICE VAR [%]'].apply(lambda x: 1 if x > 0 else (0 if x < 0 else None))
# remove irrelevant columns
df.drop(['Stocks','2019 PRICE VAR [%]'],axis=1,inplace=True)
df.shape
# Out:
# (4392, 223)

# %%
# removing duplicated columns
df = df.loc[:, ~df.T.duplicated()]
df.shape
# Out:
# (4392, 199)

# %%
df.describe()
# Out:
#             Revenue  Revenue Growth  Cost of Revenue  Gross Profit  \
# count  4.346000e+03     4253.000000     4.207000e+03  4.328000e+03
# mean   5.119639e+09        3.455278     3.144772e+09  2.043909e+09
# std    2.049586e+10      195.504906     1.508553e+10  7.681834e+09
# min   -6.894100e+07       -3.461500    -2.669055e+09 -1.818220e+09
# 25%    6.501425e+07        0.000000     3.415500e+06  3.618903e+07
# 50%    4.982640e+08        0.074900     1.741180e+08  2.219470e+08
# 75%    2.457878e+09        0.188500     1.297814e+09  9.767015e+08
# max    5.000000e+11    12739.000000     3.730000e+11  1.270000e+11
#
#        R&D Expenses  SG&A Expense  Operating Expenses  Operating Income  \
# count  4.155000e+03  4.226000e+03        4.208000e+03      4.357000e+03
# mean   1.180176e+08  9.006181e+08        1.435663e+09      6.541207e+08
# std    9.330891e+08  3.664467e+09        5.532049e+09      2.969341e+09
# min   -1.042000e+08 -1.401594e+08       -4.280000e+09     -1.455700e+10
# 25%    0.000000e+00  2.056226e+07        4.223644e+07     -5.510000e+06
# 50%    0.000000e+00  9.390450e+07        1.806253e+08      4.203800e+07
# 75%    1.450150e+07  4.117162e+08        6.796040e+08      2.862690e+08
# max    2.883700e+10  1.070000e+11        1.070000e+11      7.089800e+10
#
#        Interest Expense  Earnings before Tax  ...  \
# count      4.208000e+03         4.321000e+03  ...
# mean       1.001350e+08         5.584432e+08  ...
# std        3.780021e+08         2.639327e+09  ...
# min       -1.408252e+09        -2.177200e+10  ...
# 25%        0.000000e+00        -1.000800e+07  ...
# 50%        5.693500e+06         2.730700e+07  ...
# 75%        5.817075e+07         2.238810e+08  ...
# max        9.168000e+09         7.290300e+10  ...
#
#        5Y Dividend per Share Growth (per Share)  \
# count                               3684.000000
# mean                                  -0.010214
# std                                    0.235000
# min                                   -1.000000
# 25%                                    0.000000
# 50%                                    0.000000
# 75%                                    0.037100
# max                                    1.651400
#
#        3Y Dividend per Share Growth (per Share)  Receivables growth  \
# count                               4067.000000         4268.000000
# mean                                   0.006081           36.768524
# std                                    0.239653         2347.079237
# min                                   -1.000000           -1.000000
# 25%                                    0.000000           -0.048075
# 50%                                    0.000000            0.010200
# 75%                                    0.042050            0.185900
# max                                    4.079100       153332.333300
#
#        Inventory Growth  Asset Growth  Book Value per Share Growth  \
# count       4160.000000   4178.000000                  4121.000000
# mean           0.183066      1.389013                     0.262530
# std            4.688013     35.123904                     5.612666
# min           -1.000000     -0.999100                   -32.258100
# 25%            0.000000     -0.036700                    -0.108600
# 50%            0.000000      0.034750                     0.026100
# 75%            0.080050      0.160575                     0.138400
# max          293.473000   1184.993800                   313.395800
#
#         Debt Growth  R&D Expense Growth  SG&A Expenses Growth        Class
# count   4128.000000         4133.000000           4144.000000  4385.000000
# mean       9.928446            0.091891              0.153610     0.693044
# std      363.717734            0.823281              0.839647     0.461283
# min       -1.000000           -1.000000             -1.000000     0.000000
# 25%       -0.082850            0.000000             -0.004650     0.000000
# 50%        0.000000            0.000000              0.065700     1.000000
# 75%        0.115425            0.009700              0.167625     1.000000
# max    17646.823500           36.898100             43.718800     1.000000
#
# [8 rows x 198 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4392 entries, 0 to 4391
# Columns: 199 entries, Revenue to Class
# dtypes: float64(198), object(1)
# memory usage: 6.7+ MB

# %%
# train test split
X = df.drop('Class',axis=1)
y = df['Class']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2,random_state=0)
print(X_train.shape)
print(X_test.shape)
# Out:
# (3513, 198)
# (879, 198)

# %%
missing_percentages = round(X_train.isnull().mean() *100,2)
missing_percentages.to_csv('Missing value information.csv')

t = np.round(X_train.drop('Sector',axis=1).corr(),3)
t.to_csv('correlation matrix.csv')

# priceEarningsToGrowthRatio - 37.75%
# ebtperEBIT  - 32.81%
# niperEBT - 35.54%
# effectiveTaxRate - 35.54% 
# operatingCycle - 99.86%
# cashConversionCycle - 99.86%
# shortTermCoverageRatios - 43.8%
# dividendPayoutRatio - 37.7% 
# 10 Y revenue growth per share - 37.63%
# 10 Y operating CF growth per share - 37.47%
# 10Y net income growth per share  - 37.64%
# 10Y shareholders equity growth - 38.59%
# 10Y dividend per share growth - 36%

# %%
# Custom Transformer to Drop Columns with >40% Missing Values
class DropHighMissingColumns(BaseEstimator, TransformerMixin):
    def __init__(self, threshold=40):
        self.threshold = threshold
        self.cols_to_drop = None

    def fit(self, X, y=None):
        missing_percentage = X.isnull().mean() * 100
        self.cols_to_drop = missing_percentage[missing_percentage > self.threshold].index.tolist()
        return self

    def transform(self, X):
        return X.drop(columns=self.cols_to_drop)

# %%
class CorrelationBasedIterativeImputer(BaseEstimator, TransformerMixin):
    def __init__(self, max_iter=50, k=5, random_state=0,verbose=2):
        self.max_iter = max_iter
        self.k = k
        self.random_state = random_state
        self.imputers = {}  # Store imputers per column
        self.cols_info = {}  # Store top-k correlated cols per column
        self.columns = None
        self.verbose = verbose

    def fit(self, X, y=None):
        X = X.copy()
        self.columns = X.columns
        corr_matrix = X.corr()

        for col in X.columns:
            if X[col].isnull().any():
                # Drop col from corr to avoid self-correlation
                corrs = corr_matrix[col].drop(index=col).abs().sort_values(ascending=False)
                top_k_features = corrs.head(self.k).index.tolist()

                # Include the target column itself for imputation
                used_features = top_k_features + [col]

                # Subset with only those columns
                X_subset = X[used_features]

                imputer = IterativeImputer(max_iter=self.max_iter, verbose=self.verbose,random_state=self.random_state)
                imputer.fit(X_subset)

                self.imputers[col] = imputer
                self.cols_info[col] = used_features

        return self

    def transform(self, X):
        X = X.copy()

        for col, imputer in self.imputers.items():
            used_features = self.cols_info[col]

            # Only transform the subset of used features
            X_subset = X[used_features]

            # Check for missing columns due to dropping or other preprocessing
            if any(feature not in X.columns for feature in used_features):
                continue  # or raise a warning

            X_imputed = imputer.transform(X_subset)

            # Update only the column being imputed in the original X
            X[col] = X_imputed[:, used_features.index(col)]

        return X[self.columns]  # Ensures you return all original columns, in original order

# %%
pipeline = Pipeline([
    ('drop_missing', DropHighMissingColumns(threshold=40)),
    ('missing_imputation',CorrelationBasedIterativeImputer(max_iter=100,k=5))
    # Add other steps here
])

# %%
sector_train= X_train['Sector']
X_train = pipeline.fit_transform(X_train.drop('Sector',axis=1))
X_train['Sector'] = sector_train.reset_index(drop=True)

'''sector_test= X_test['Sector']
X_test = pipeline.transform(X_test.drop('Sector',axis=1))
X_test['Sector'] = sector_test.reset_index(drop=True)'''
# Out:
# [IterativeImputer] Completing matrix with shape (3513, 6)
# [IterativeImputer] Ending imputation round 1/100, elapsed time 0.05
# [IterativeImputer] Change: 126569680748.18373, scaled tolerance: 500000000.0
# [IterativeImputer] Ending imputation round 2/100, elapsed time 0.07
# [IterativeImputer] Change: 29676230850.23197, scaled tolerance: 500000000.0
# [IterativeImputer] Ending imputation round 3/100, elapsed time 0.10
# [IterativeImputer] Change: 3835596506.0753574, scaled tolerance: 500000000.0
# [IterativeImputer] Ending imputation round 4/100, elapsed time 0.11
# [IterativeImputer] Change: 6308576081.715153, scaled tolerance: 500000000.0
# [IterativeImputer] Ending imputation round 5/100, elapsed time 0.15
# [IterativeImputer] Change: 5613636630.916874, scaled tolerance: 500000000.0
# [IterativeImputer] Ending imputation round 6/100, elapsed time 0.16
# [IterativeImputer] Change: 4136200780.5515404, scaled tolerance: 500000000.0
# [IterativeImputer] Ending imputation round 7/100, elapsed time 0.19
# [IterativeImputer] Change: 2865646678.433031, scaled tolerance: 500000000.0
# [IterativeImputer] Ending imputation round 8/100, elapsed time 0.23
# [IterativeImputer] Change: 1938596613.7904263, scaled tolerance: 500000000.0
# [IterativeImputer] Ending imputation round 9/100, elapsed time 0.25
# [IterativeImputer] Change: 1298410165.5724258, scaled tolerance: 500000000.0
# [IterativeImputer] Ending imputation round 10/100, elapsed time 0.28
# [IterativeImputer] Change: 865668228.9856339, scaled tolerance: 500000000.0
# [IterativeImputer] Ending imputation round 11/100, elapsed time 0.30
# [IterativeImputer] Change: 575709692.4479485, scaled tolerance: 500000000.0
# [IterativeImputer] Ending imputation round 12/100, elapsed time 0.32
# [IterativeImputer] Change: 382151429.06783867, scaled tolerance: 500000000.0
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (3513, 6)
# [IterativeImputer] Ending imputation round 1/100, elapsed time 0.02
# [IterativeImputer] Change: 1970.1675502720043, scaled tolerance: 12.739
# [IterativeImputer] Ending imputation round 2/100, elapsed time 0.06
# [IterativeImputer] Change: 68.61639384116665, scaled tolerance: 12.739
# [IterativeImputer] Ending imputation round 3/100, elapsed time 0.08
# [IterativeImputer] Change: 131.7081430133387, scaled tolerance: 12.739
# [IterativeImputer] Ending imputation round 4/100, elapsed time 0.10
# [IterativeImputer] Change: 98.13541988313773, scaled tolerance: 12.739
# [IterativeImputer] Ending imputation round 5/100, elapsed time 0.14
# [IterativeImputer] Change: 24.255347766210434, scaled tolerance: 12.739
# [IterativeImputer] Ending imputation round 6/100, elapsed time 0.17
# [IterativeImputer] Change: 4.0950547886512885, scaled tolerance: 12.739
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (3513, 6)
# [IterativeImputer] Ending imputation round 1/100, elapsed time 0.03
# [IterativeImputer] Change: 137849979154.4388, scaled tolerance: 500000000.0
# [IterativeImputer] Ending imputation round 2/100, elapsed time 0.05
# [IterativeImputer] Change: 3765852503.1050253, scaled tolerance: 500000000.0
# [IterativeImputer] Ending imputation round 3/100, elapsed time 0.06
# [IterativeImputer] Change: 1564240532.2382514, scaled tolerance: 500000000.0
# [IterativeImputer] Ending imputation round 4/100, elapsed time 0.11
# [IterativeImputer] Change: 648838236.2184935, scaled tolerance: 500000000.0
# [IterativeImputer] Ending imputation round 5/100, elapsed time 0.13
# [IterativeImputer] Change: 270148675.26438355, scaled tolerance: 500000000.0
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (3513, 6)
# [IterativeImputer] Ending imputation round 1/100, elapsed time 0.03
# [IterativeImputer] Change: 42758663425.64297, scaled tolerance: 127000000.0
# [IterativeImputer] Ending imputation round 2/100, elapsed time 0.06
# [IterativeImputer] Change: 12231139794.88473, scaled tolerance: 127000000.0
# [IterativeImputer] Ending imputation round 3/100, elapsed time 0.08
# [IterativeImputer] Change: 6380291150.226456, scaled tolerance: 127000000.0
# [IterativeImputer] Ending imputation round 4/100, elapsed time 0.11
# [IterativeImputer] Change: 3074691803.2455935, scaled tolerance: 127000000.0
# [IterativeImputer] Ending imputation round 5/100, elapsed time 0.13
# [IterativeImputer] Change: 1574175403.1852791, scaled tolerance: 127000000.0
# [IterativeImputer] Ending imputation round 6/100, elapsed time 0.15
# [IterativeImputer] Change: 863085054.3245032, scaled tolerance: 127000000.0
# [IterativeImputer] Ending imputation round 7/100, elapsed time 0.18
# [IterativeImputer] Change: 525796656.5643344, scaled tolerance: 127000000.0
# [IterativeImputer] Ending imputation round 8/100, elapsed time 0.20
# [IterativeImputer] Change: 405768514.70074654, scaled tolerance: 127000000.0
# [IterativeImputer] Ending imputation round 9/100, elapsed time 0.23
# [IterativeImputer] Change: 391728952.03423, scaled tolerance: 127000000.0
# [IterativeImputer] Ending imputation round 10/100, elapsed time 0.26
# [IterativeImputer] Change: 383801454.12103367, scaled tolerance: 127000000.0
# [IterativeImputer] Ending imputation round 11/100, elapsed time 0.29
# [IterativeImputer] Change: 378758420.30203676, scaled tolerance: 127000000.0
# [IterativeImputer] Ending imputation round 12/100, elapsed time 0.31
# [IterativeImputer] Change: 375077961.3437896, scaled tolerance: 127000000.0
# [IterativeImputer] Ending imputation round 13/100, elapsed time 0.34
# [IterativeImputer] Change: 372043292.08867455, scaled tolerance: 127000000.0
# [IterativeImputer] Ending imputation round 14/100, elapsed time 0.36
# [IterativeImputer] Change: 369317501.7723532, scaled tolerance: 127000000.0
# [IterativeImputer] Ending imputation round 15/100, elapsed time 0.38
# [IterativeImputer] Change: 366742736.4981241, scaled tolerance: 127000000.0
# [IterativeImputer] Ending imputation round 16/100, elapsed time 0.41
# [IterativeImputer] Change: 364245392.7556505, scaled tolerance: 127000000.0
# [IterativeImputer] Ending imputation round 17/100, elapsed time 0.43
# [IterativeImputer] Change: 361791396.9298291, scaled tolerance: 127000000.0
# [IterativeImputer] Ending imputation round 18/100, elapsed time 0.45
# [IterativeImputer] Change: 359365141.757874, scaled tolerance: 127000000.0
# [IterativeImputer] Ending imputation round 19/100, elapsed time 0.48
# [IterativeImputer] Change: 356959588.67318106, scaled tolerance: 127000000.0
# [IterativeImputer] Ending imputation round 20/100, elapsed time 0.51
# [IterativeImputer] Change: 354571633.86683273, scaled tolerance: 127000000.0
# [IterativeImputer] Ending imputation round 21/100, elapsed time 0.54
# [IterativeImputer] Change: 352199950.85306215, scaled tolerance: 127000000.0
# [IterativeImputer] Ending imputation round 22/100, elapsed time 0.56
# [IterativeImputer] Change: 349843994.6676936, scaled tolerance: 127000000.0
# [IterativeImputer] Ending imputation round 23/100, elapsed time 0.58
# [IterativeImputer] Change: 347503548.4237189, scaled tolerance: 127000000.0
# [IterativeImputer] Ending imputation round 24/100, elapsed time 0.61
# [IterativeImputer] Change: 345178521.2841549, scaled tolerance: 127000000.0
# [IterativeImputer] Ending imputation round 25/100, elapsed time 0.64
# [IterativeImputer] Change: 342868861.7029371, scaled tolerance: 127000000.0
# [IterativeImputer] Ending imputation round 26/100, elapsed time 0.67
# [IterativeImputer] Change: 340574522.58694744, scaled tolerance: 127000000.0
# [IterativeImputer] Ending imputation round 27/100, elapsed time 0.70
# [IterativeImputer] Change: 338295449.176054, scaled tolerance: 127000000.0
# [IterativeImputer] Ending imputation round 28/100, elapsed time 0.73
# [IterativeImputer] Change: 336031576.37402153, scaled tolerance: 127000000.0
# [IterativeImputer] Ending imputation round 29/100, elapsed time 0.75
# [IterativeImputer] Change: 333782829.6284332, scaled tolerance: 127000000.0
# [IterativeImputer] Ending imputation round 30/100, elapsed time 0.78
# [IterativeImputer] Change: 331549126.8557396, scaled tolerance: 127000000.0
# [IterativeImputer] Ending imputation round 31/100, elapsed time 0.79
# [IterativeImputer] Change: 329330380.39966774, scaled tolerance: 127000000.0
# [IterativeImputer] Ending imputation round 32/100, elapsed time 0.81
# [IterativeImputer] Change: 327126498.6945257, scaled tolerance: 127000000.0
# [IterativeImputer] Ending imputation round 33/100, elapsed time 0.84
# [IterativeImputer] Change: 324937387.56649876, scaled tolerance: 127000000.0
# [IterativeImputer] Ending imputation round 34/100, elapsed time 0.88
# [IterativeImputer] Change: 322762951.20252895, scaled tolerance: 127000000.0
# [IterativeImputer] Ending imputation round 35/100, elapsed time 0.89
# [IterativeImputer] Change: 320603092.8603182, scaled tolerance: 127000000.0
# [IterativeImputer] Ending imputation round 36/100, elapsed time 0.93
# [IterativeImputer] Change: 318457715.37437534, scaled tolerance: 127000000.0
# [IterativeImputer] Ending imputation round 37/100, elapsed time 0.96
# [IterativeImputer] Change: 316326721.5123949, scaled tolerance: 127000000.0
# [IterativeImputer] Ending imputation round 38/100, elapsed time 0.99
# [IterativeImputer] Change: 314210014.22700214, scaled tolerance: 127000000.0
# [IterativeImputer] Ending imputation round 39/100, elapsed time 1.00
# [IterativeImputer] Change: 312107496.8281822, scaled tolerance: 127000000.0
# [IterativeImputer] Ending imputation round 40/100, elapsed time 1.03
# [IterativeImputer] Change: 310019073.10009, scaled tolerance: 127000000.0
# [IterativeImputer] Ending imputation round 41/100, elapsed time 1.05
# [IterativeImputer] Change: 307944647.3827839, scaled tolerance: 127000000.0
# [IterativeImputer] Ending imputation round 42/100, elapsed time 1.06
# [IterativeImputer] Change: 305884124.62246513, scaled tolerance: 127000000.0
# [IterativeImputer] Ending imputation round 43/100, elapsed time 1.09
# [IterativeImputer] Change: 303837410.40713215, scaled tolerance: 127000000.0
# [IterativeImputer] Ending imputation round 44/100, elapsed time 1.11
# [IterativeImputer] Change: 301804410.98618793, scaled tolerance: 127000000.0
# [IterativeImputer] Ending imputation round 45/100, elapsed time 1.13
# [IterativeImputer] Change: 299785033.28099155, scaled tolerance: 127000000.0
# [IterativeImputer] Ending imputation round 46/100, elapsed time 1.16
# [IterativeImputer] Change: 297779184.89045715, scaled tolerance: 127000000.0
# [IterativeImputer] Ending imputation round 47/100, elapsed time 1.18
# [IterativeImputer] Change: 295786774.09330463, scaled tolerance: 127000000.0
# [IterativeImputer] Ending imputation round 48/100, elapsed time 1.20
# [IterativeImputer] Change: 293807709.84195423, scaled tolerance: 127000000.0
# [IterativeImputer] Ending imputation round 49/100, elapsed time 1.23
# [IterativeImputer] Change: 291841901.76208305, scaled tolerance: 127000000.0
# [IterativeImputer] Ending imputation round 50/100, elapsed time 1.25
# [IterativeImputer] Change: 289889260.1461086, scaled tolerance: 127000000.0
# [IterativeImputer] Ending imputation round 51/100, elapsed time 1.28
# [IterativeImputer] Change: 287949695.94549656, scaled tolerance: 127000000.0
# [IterativeImputer] Ending imputation round 52/100, elapsed time 1.30
# [IterativeImputer] Change: 286023120.7656889, scaled tolerance: 127000000.0
# [IterativeImputer] Ending imputation round 53/100, elapsed time 1.31
# [IterativeImputer] Change: 284109446.8591728, scaled tolerance: 127000000.0
# [IterativeImputer] Ending imputation round 54/100, elapsed time 1.34
# [IterativeImputer] Change: 282208587.11762714, scaled tolerance: 127000000.0
# [IterativeImputer] Ending imputation round 55/100, elapsed time 1.38
# [IterativeImputer] Change: 280320455.06420803, scaled tolerance: 127000000.0
# [IterativeImputer] Ending imputation round 56/100, elapsed time 1.41
# [IterativeImputer] Change: 278444964.84904957, scaled tolerance: 127000000.0
# [IterativeImputer] Ending imputation round 57/100, elapsed time 1.44
# [IterativeImputer] Change: 276582031.23981285, scaled tolerance: 127000000.0
# [IterativeImputer] Ending imputation round 58/100, elapsed time 1.46
# [IterativeImputer] Change: 274731569.61604595, scaled tolerance: 127000000.0
# [IterativeImputer] Ending imputation round 59/100, elapsed time 1.49
# [IterativeImputer] Change: 272893495.96284866, scaled tolerance: 127000000.0
# [IterativeImputer] Ending imputation round 60/100, elapsed time 1.51
# [IterativeImputer] Change: 271067726.8639078, scaled tolerance: 127000000.0
# [IterativeImputer] Ending imputation round 61/100, elapsed time 1.54
# [IterativeImputer] Change: 269254179.4953165, scaled tolerance: 127000000.0
# [IterativeImputer] Ending imputation round 62/100, elapsed time 1.56
# [IterativeImputer] Change: 267452771.61983395, scaled tolerance: 127000000.0
# [IterativeImputer] Ending imputation round 63/100, elapsed time 1.59
# [IterativeImputer] Change: 265663421.58078194, scaled tolerance: 127000000.0
# [IterativeImputer] Ending imputation round 64/100, elapsed time 1.62
# [IterativeImputer] Change: 263886048.295743, scaled tolerance: 127000000.0
# [IterativeImputer] Ending imputation round 65/100, elapsed time 1.64
# [IterativeImputer] Change: 262120571.25243282, scaled tolerance: 127000000.0
# [IterativeImputer] Ending imputation round 66/100, elapsed time 1.66
# [IterativeImputer] Change: 260366910.50075722, scaled tolerance: 127000000.0
# [IterativeImputer] Ending imputation round 67/100, elapsed time 1.68
# [IterativeImputer] Change: 258624986.64985466, scaled tolerance: 127000000.0
# [IterativeImputer] Ending imputation round 68/100, elapsed time 1.71
# [IterativeImputer] Change: 256894720.86192322, scaled tolerance: 127000000.0
# [IterativeImputer] Ending imputation round 69/100, elapsed time 1.72
# [IterativeImputer] Change: 255176034.84694386, scaled tolerance: 127000000.0
# [IterativeImputer] Ending imputation round 70/100, elapsed time 1.74
# [IterativeImputer] Change: 253468850.85813236, scaled tolerance: 127000000.0
# [IterativeImputer] Ending imputation round 71/100, elapsed time 1.78
# [IterativeImputer] Change: 251773091.68616962, scaled tolerance: 127000000.0
# [IterativeImputer] Ending imputation round 72/100, elapsed time 1.80
# [IterativeImputer] Change: 250088680.65583992, scaled tolerance: 127000000.0
# [IterativeImputer] Ending imputation round 73/100, elapsed time 1.83
# [IterativeImputer] Change: 248415541.62052822, scaled tolerance: 127000000.0
# [IterativeImputer] Ending imputation round 74/100, elapsed time 1.86
# [IterativeImputer] Change: 246753598.95822334, scaled tolerance: 127000000.0
# [IterativeImputer] Ending imputation round 75/100, elapsed time 1.88
# [IterativeImputer] Change: 245102777.56578922, scaled tolerance: 127000000.0
# [IterativeImputer] Ending imputation round 76/100, elapsed time 1.91
# [IterativeImputer] Change: 243463002.85653496, scaled tolerance: 127000000.0
# [IterativeImputer] Ending imputation round 77/100, elapsed time 1.93
# [IterativeImputer] Change: 241834200.75415993, scaled tolerance: 127000000.0
# [IterativeImputer] Ending imputation round 78/100, elapsed time 1.95
# [IterativeImputer] Change: 240216297.6893053, scaled tolerance: 127000000.0
# [IterativeImputer] Ending imputation round 79/100, elapsed time 1.98
# [IterativeImputer] Change: 238609220.5962124, scaled tolerance: 127000000.0
# [IterativeImputer] Ending imputation round 80/100, elapsed time 2.00
# [IterativeImputer] Change: 237012896.9071226, scaled tolerance: 127000000.0
# [IterativeImputer] Ending imputation round 81/100, elapsed time 2.01
# [IterativeImputer] Change: 235427254.54953098, scaled tolerance: 127000000.0
# [IterativeImputer] Ending imputation round 82/100, elapsed time 2.05
# [IterativeImputer] Change: 233852221.9414177, scaled tolerance: 127000000.0
# [IterativeImputer] Ending imputation round 83/100, elapsed time 2.06
# [IterativeImputer] Change: 232287727.9885559, scaled tolerance: 127000000.0
# [IterativeImputer] Ending imputation round 84/100, elapsed time 2.08
# [IterativeImputer] Change: 230733702.0791998, scaled tolerance: 127000000.0
# [IterativeImputer] Ending imputation round 85/100, elapsed time 2.10
# [IterativeImputer] Change: 229190074.0812168, scaled tolerance: 127000000.0
# [IterativeImputer] Ending imputation round 86/100, elapsed time 2.12
# [IterativeImputer] Change: 227656774.33886242, scaled tolerance: 127000000.0
# [IterativeImputer] Ending imputation round 87/100, elapsed time 2.13
# [IterativeImputer] Change: 226133733.66818237, scaled tolerance: 127000000.0
# [IterativeImputer] Ending imputation round 88/100, elapsed time 2.15
# [IterativeImputer] Change: 224620883.35448074, scaled tolerance: 127000000.0
# [IterativeImputer] Ending imputation round 89/100, elapsed time 2.16
# [IterativeImputer] Change: 223118155.14703178, scaled tolerance: 127000000.0
# [IterativeImputer] Ending imputation round 90/100, elapsed time 2.20
# [IterativeImputer] Change: 221625481.25859833, scaled tolerance: 127000000.0
# [IterativeImputer] Ending imputation round 91/100, elapsed time 2.21
# [IterativeImputer] Change: 220142794.35826206, scaled tolerance: 127000000.0
# [IterativeImputer] Ending imputation round 92/100, elapsed time 2.25
# [IterativeImputer] Change: 218670027.57147598, scaled tolerance: 127000000.0
# [IterativeImputer] Ending imputation round 93/100, elapsed time 2.28
# [IterativeImputer] Change: 217207114.47511387, scaled tolerance: 127000000.0
# [IterativeImputer] Ending imputation round 94/100, elapsed time 2.30
# [IterativeImputer] Change: 215753989.09311962, scaled tolerance: 127000000.0
# [IterativeImputer] Ending imputation round 95/100, elapsed time 2.33
# [IterativeImputer] Change: 214310585.89566135, scaled tolerance: 127000000.0
# [IterativeImputer] Ending imputation round 96/100, elapsed time 2.35
# [IterativeImputer] Change: 212876839.7947178, scaled tolerance: 127000000.0
# [IterativeImputer] Ending imputation round 97/100, elapsed time 2.37
# [IterativeImputer] Change: 211452686.14018726, scaled tolerance: 127000000.0
# [IterativeImputer] Ending imputation round 98/100, elapsed time 2.38
# [IterativeImputer] Change: 210038060.71756554, scaled tolerance: 127000000.0
# [IterativeImputer] Ending imputation round 99/100, elapsed time 2.42
# [IterativeImputer] Change: 208632899.7452097, scaled tolerance: 127000000.0
# [IterativeImputer] Ending imputation round 100/100, elapsed time 2.44
# [IterativeImputer] Change: 207237139.870286, scaled tolerance: 127000000.0
# C:\Users\Riya\anaconda3\Lib\site-packages\sklearn\impute\_iterative.py:825: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   warnings.warn(
# [IterativeImputer] Completing matrix with shape (3513, 6)
# [IterativeImputer] Ending imputation round 1/100, elapsed time 0.02
# [IterativeImputer] Change: 728769856943.3253, scaled tolerance: 1150000000.0
# [IterativeImputer] Ending imputation round 2/100, elapsed time 0.04
# [IterativeImputer] Change: 22623180642.84128, scaled tolerance: 1150000000.0
# [IterativeImputer] Ending imputation round 3/100, elapsed time 0.07
# [IterativeImputer] Change: 15641929523.785017, scaled tolerance: 1150000000.0
# [IterativeImputer] Ending imputation round 4/100, elapsed time 0.10
# [IterativeImputer] Change: 9927402917.95523, scaled tolerance: 1150000000.0
# [IterativeImputer] Ending imputation round 5/100, elapsed time 0.12
# [IterativeImputer] Change: 6361479828.613089, scaled tolerance: 1150000000.0
# [IterativeImputer] Ending imputation round 6/100, elapsed time 0.13
# [IterativeImputer] Change: 4075302072.684041, scaled tolerance: 1150000000.0
# [IterativeImputer] Ending imputation round 7/100, elapsed time 0.17
# [IterativeImputer] Change: 2609560400.8917384, scaled tolerance: 1150000000.0
# [IterativeImputer] Ending imputation round 8/100, elapsed time 0.18
# [IterativeImputer] Change: 1669667750.3865623, scaled tolerance: 1150000000.0
# [IterativeImputer] Ending imputation round 9/100, elapsed time 0.22
# [IterativeImputer] Change: 1067070836.7988212, scaled tolerance: 1150000000.0
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (3513, 6)
# [IterativeImputer] Ending imputation round 1/100, elapsed time 0.02
# [IterativeImputer] Change: 35484673074.27751, scaled tolerance: 500000000.0
# [IterativeImputer] Ending imputation round 2/100, elapsed time 0.04
# [IterativeImputer] Change: 13883593877.744282, scaled tolerance: 500000000.0
# [IterativeImputer] Ending imputation round 3/100, elapsed time 0.06
# [IterativeImputer] Change: 5096389656.522678, scaled tolerance: 500000000.0
# [IterativeImputer] Ending imputation round 4/100, elapsed time 0.08
# [IterativeImputer] Change: 4688134038.567129, scaled tolerance: 500000000.0
# [IterativeImputer] Ending imputation round 5/100, elapsed time 0.10
# [IterativeImputer] Change: 4560529999.619158, scaled tolerance: 500000000.0
# [IterativeImputer] Ending imputation round 6/100, elapsed time 0.12
# [IterativeImputer] Change: 4388874507.743198, scaled tolerance: 500000000.0
# [IterativeImputer] Ending imputation round 7/100, elapsed time 0.15
# [IterativeImputer] Change: 4200885178.3783193, scaled tolerance: 500000000.0
# [IterativeImputer] Ending imputation round 8/100, elapsed time 0.17
# [IterativeImputer] Change: 4007803883.465024, scaled tolerance: 500000000.0
# [IterativeImputer] Ending imputation round 9/100, elapsed time 0.19
# [IterativeImputer] Change: 3815654191.658135, scaled tolerance: 500000000.0
# [IterativeImputer] Ending imputation round 10/100, elapsed time 0.22
# [IterativeImputer] Change: 3627855041.972919, scaled tolerance: 500000000.0
# [IterativeImputer] Ending imputation round 11/100, elapsed time 0.25
# [IterativeImputer] Change: 3446310004.5655046, scaled tolerance: 500000000.0
# [IterativeImputer] Ending imputation round 12/100, elapsed time 0.27
# [IterativeImputer] Change: 3272008803.85335, scaled tolerance: 500000000.0
# [IterativeImputer] Ending imputation round 13/100, elapsed time 0.29
# [IterativeImputer] Change: 3105387981.611683, scaled tolerance: 500000000.0
# [IterativeImputer] Ending imputation round 14/100, elapsed time 0.31
# [IterativeImputer] Change: 2946551688.6228213, scaled tolerance: 500000000.0
# [IterativeImputer] Ending imputation round 15/100, elapsed time 0.32
# [IterativeImputer] Change: 2795407381.281842, scaled tolerance: 500000000.0
# [IterativeImputer] Ending imputation round 16/100, elapsed time 0.34
# [IterativeImputer] Change: 2651749153.270342, scaled tolerance: 500000000.0
# [IterativeImputer] Ending imputation round 17/100, elapsed time 0.36
# [IterativeImputer] Change: 2515308770.7240305, scaled tolerance: 500000000.0
# [IterativeImputer] Ending imputation round 18/100, elapsed time 0.39
# [IterativeImputer] Change: 2385786787.8841, scaled tolerance: 500000000.0
# [IterativeImputer] Ending imputation round 19/100, elapsed time 0.41
# [IterativeImputer] Change: 2262871384.1576023, scaled tolerance: 500000000.0
# [IterativeImputer] Ending imputation round 20/100, elapsed time 0.44
# [IterativeImputer] Change: 2146249639.5554667, scaled tolerance: 500000000.0
# [IterativeImputer] Ending imputation round 21/100, elapsed time 0.47
# [IterativeImputer] Change: 2035614159.8269758, scaled tolerance: 500000000.0
# [IterativeImputer] Ending imputation round 22/100, elapsed time 0.49
# [IterativeImputer] Change: 1930666847.7694283, scaled tolerance: 500000000.0
# [IterativeImputer] Ending imputation round 23/100, elapsed time 0.51
# [IterativeImputer] Change: 1831120928.8990936, scaled tolerance: 500000000.0
# [IterativeImputer] Ending imputation round 24/100, elapsed time 0.53
# [IterativeImputer] Change: 1736701914.8499346, scaled tolerance: 500000000.0
# [IterativeImputer] Ending imputation round 25/100, elapsed time 0.57
# [IterativeImputer] Change: 1647147925.6026926, scaled tolerance: 500000000.0
# [IterativeImputer] Ending imputation round 26/100, elapsed time 0.58
# [IterativeImputer] Change: 1562209629.8015165, scaled tolerance: 500000000.0
# [IterativeImputer] Ending imputation round 27/100, elapsed time 0.62
# [IterativeImputer] Change: 1481649962.5257988, scaled tolerance: 500000000.0
# [IterativeImputer] Ending imputation round 28/100, elapsed time 0.63
# [IterativeImputer] Change: 1405243718.23623, scaled tolerance: 500000000.0
# [IterativeImputer] Ending imputation round 29/100, elapsed time 0.67
# [IterativeImputer] Change: 1332777078.6121101, scaled tolerance: 500000000.0
# [IterativeImputer] Ending imputation round 30/100, elapsed time 0.68
# [IterativeImputer] Change: 1264047111.5257587, scaled tolerance: 500000000.0
# [IterativeImputer] Ending imputation round 31/100, elapsed time 0.71
# [IterativeImputer] Change: 1198861262.977789, scaled tolerance: 500000000.0
# [IterativeImputer] Ending imputation round 32/100, elapsed time 0.73
# [IterativeImputer] Change: 1137036854.9029055, scaled tolerance: 500000000.0
# [IterativeImputer] Ending imputation round 33/100, elapsed time 0.75
# [IterativeImputer] Change: 1078400596.307478, scaled tolerance: 500000000.0
# [IterativeImputer] Ending imputation round 34/100, elapsed time 0.78
# [IterativeImputer] Change: 1022788111.8434725, scaled tolerance: 500000000.0
# [IterativeImputer] Ending imputation round 35/100, elapsed time 0.80
# [IterativeImputer] Change: 970043489.8828783, scaled tolerance: 500000000.0
# [IterativeImputer] Ending imputation round 36/100, elapsed time 0.83
# [IterativeImputer] Change: 920018850.9230757, scaled tolerance: 500000000.0
# [IterativeImputer] Ending imputation round 37/100, elapsed time 0.85
# [IterativeImputer] Change: 872573936.4025068, scaled tolerance: 500000000.0
# [IterativeImputer] Ending imputation round 38/100, elapsed time 0.88
# [IterativeImputer] Change: 827575717.5784492, scaled tolerance: 500000000.0
# [IterativeImputer] Ending imputation round 39/100, elapsed time 0.90
# [IterativeImputer] Change: 784898023.8675823, scaled tolerance: 500000000.0
# [IterativeImputer] Ending imputation round 40/100, elapsed time 0.93
# [IterativeImputer] Change: 744421189.9103212, scaled tolerance: 500000000.0
# [IterativeImputer] Ending imputation round 41/100, elapsed time 0.96
# [IterativeImputer] Change: 706031720.5633993, scaled tolerance: 500000000.0
# [IterativeImputer] Ending imputation round 42/100, elapsed time 0.98
# [IterativeImputer] Change: 669621972.997364, scaled tolerance: 500000000.0
# [IterativeImputer] Ending imputation round 43/100, elapsed time 1.02
# [IterativeImputer] Change: 635089855.0830631, scaled tolerance: 500000000.0
# [IterativeImputer] Ending imputation round 44/100, elapsed time 1.03
# [IterativeImputer] Change: 602338539.2622776, scaled tolerance: 500000000.0
# [IterativeImputer] Ending imputation round 45/100, elapsed time 1.07
# [IterativeImputer] Change: 571276191.1370869, scaled tolerance: 500000000.0
# [IterativeImputer] Ending imputation round 46/100, elapsed time 1.08
# [IterativeImputer] Change: 541815712.0233765, scaled tolerance: 500000000.0
# [IterativeImputer] Ending imputation round 47/100, elapsed time 1.12
# [IterativeImputer] Change: 513874494.76974106, scaled tolerance: 500000000.0
# [IterativeImputer] Ending imputation round 48/100, elapsed time 1.14
# [IterativeImputer] Change: 487374192.1526871, scaled tolerance: 500000000.0
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (3513, 6)
# [IterativeImputer] Ending imputation round 1/100, elapsed time 0.02
# [IterativeImputer] Change: 35484673074.277466, scaled tolerance: 500000000.0
# [IterativeImputer] Ending imputation round 2/100, elapsed time 0.04
# [IterativeImputer] Change: 13883593877.744028, scaled tolerance: 500000000.0
# [IterativeImputer] Ending imputation round 3/100, elapsed time 0.07
# [IterativeImputer] Change: 5096389656.522678, scaled tolerance: 500000000.0
# [IterativeImputer] Ending imputation round 4/100, elapsed time 0.10
# [IterativeImputer] Change: 4688134038.567148, scaled tolerance: 500000000.0
# [IterativeImputer] Ending imputation round 5/100, elapsed time 0.12
# [IterativeImputer] Change: 4560529999.619024, scaled tolerance: 500000000.0
# [IterativeImputer] Ending imputation round 6/100, elapsed time 0.14
# [IterativeImputer] Change: 4388874507.742941, scaled tolerance: 500000000.0
# [IterativeImputer] Ending imputation round 7/100, elapsed time 0.17
# [IterativeImputer] Change: 4200885178.3783493, scaled tolerance: 500000000.0
# [IterativeImputer] Ending imputation round 8/100, elapsed time 0.20
# [IterativeImputer] Change: 4007803883.4648046, scaled tolerance: 500000000.0
# [IterativeImputer] Ending imputation round 9/100, elapsed time 0.23
# [IterativeImputer] Change: 3815654191.6581407, scaled tolerance: 500000000.0
# [IterativeImputer] Ending imputation round 10/100, elapsed time 0.27
# [IterativeImputer] Change: 3627855041.972629, scaled tolerance: 500000000.0
# [IterativeImputer] Ending imputation round 11/100, elapsed time 0.28
# [IterativeImputer] Change: 3446310004.5653124, scaled tolerance: 500000000.0
# [IterativeImputer] Ending imputation round 12/100, elapsed time 0.30
# [IterativeImputer] Change: 3272008803.853156, scaled tolerance: 500000000.0
# [IterativeImputer] Ending imputation round 13/100, elapsed time 0.33
# [IterativeImputer] Change: 3105387981.611599, scaled tolerance: 500000000.0
# [IterativeImputer] Ending imputation round 14/100, elapsed time 0.35
# [IterativeImputer] Change: 2946551688.6224174, scaled tolerance: 500000000.0
# [IterativeImputer] Ending imputation round 15/100, elapsed time 0.37
# [IterativeImputer] Change: 2795407381.2819786, scaled tolerance: 500000000.0
# [IterativeImputer] Ending imputation round 16/100, elapsed time 0.40
# [IterativeImputer] Change: 2651749153.2704906, scaled tolerance: 500000000.0
# [IterativeImputer] Ending imputation round 17/100, elapsed time 0.42
# [IterativeImputer] Change: 2515308770.7238855, scaled tolerance: 500000000.0
# [IterativeImputer] Ending imputation round 18/100, elapsed time 0.43
# [IterativeImputer] Change: 2385786787.8839035, scaled tolerance: 500000000.0
# [IterativeImputer] Ending imputation round 19/100, elapsed time 0.47
# [IterativeImputer] Change: 2262871384.158037, scaled tolerance: 500000000.0
# [IterativeImputer] Ending imputation round 20/100, elapsed time 0.48
# [IterativeImputer] Change: 2146249639.555112, scaled tolerance: 500000000.0
# [IterativeImputer] Ending imputation round 21/100, elapsed time 0.50
# [IterativeImputer] Change: 2035614159.8272495, scaled tolerance: 500000000.0
# [IterativeImputer] Ending imputation round 22/100, elapsed time 0.52
# [IterativeImputer] Change: 1930666847.769433, scaled tolerance: 500000000.0
# [IterativeImputer] Ending imputation round 23/100, elapsed time 0.53
# [IterativeImputer] Change: 1831120928.8990326, scaled tolerance: 500000000.0
# [IterativeImputer] Ending imputation round 24/100, elapsed time 0.57
# [IterativeImputer] Change: 1736701914.8499918, scaled tolerance: 500000000.0
# [IterativeImputer] Ending imputation round 25/100, elapsed time 0.59
# [IterativeImputer] Change: 1647147925.6026087, scaled tolerance: 500000000.0
# [IterativeImputer] Ending imputation round 26/100, elapsed time 0.61
# [IterativeImputer] Change: 1562209629.8015623, scaled tolerance: 500000000.0
# [IterativeImputer] Ending imputation round 27/100, elapsed time 0.63
# [IterativeImputer] Change: 1481649962.5259438, scaled tolerance: 500000000.0
# [IterativeImputer] Ending imputation round 28/100, elapsed time 0.64
# [IterativeImputer] Change: 1405243718.2363071, scaled tolerance: 500000000.0
# [IterativeImputer] Ending imputation round 29/100, elapsed time 0.67
# [IterativeImputer] Change: 1332777078.6121778, scaled tolerance: 500000000.0
# [IterativeImputer] Ending imputation round 30/100, elapsed time 0.70
# [IterativeImputer] Change: 1264047111.5258913, scaled tolerance: 500000000.0
# [IterativeImputer] Ending imputation round 31/100, elapsed time 0.72
# [IterativeImputer] Change: 1198861262.9779139, scaled tolerance: 500000000.0
# [IterativeImputer] Ending imputation round 32/100, elapsed time 0.74
# [IterativeImputer] Change: 1137036854.9028873, scaled tolerance: 500000000.0
# [IterativeImputer] Ending imputation round 33/100, elapsed time 0.76
# [IterativeImputer] Change: 1078400596.3076572, scaled tolerance: 500000000.0
# [IterativeImputer] Ending imputation round 34/100, elapsed time 0.79
# [IterativeImputer] Change: 1022788111.8432779, scaled tolerance: 500000000.0
# [IterativeImputer] Ending imputation round 35/100, elapsed time 0.80
# [IterativeImputer] Change: 970043489.8829365, scaled tolerance: 500000000.0
# [IterativeImputer] Ending imputation round 36/100, elapsed time 0.83
# [IterativeImputer] Change: 920018850.923109, scaled tolerance: 500000000.0
# [IterativeImputer] Ending imputation round 37/100, elapsed time 0.85
# [IterativeImputer] Change: 872573936.4024563, scaled tolerance: 500000000.0
# [IterativeImputer] Ending imputation round 38/100, elapsed time 0.88
# [IterativeImputer] Change: 827575717.5784178, scaled tolerance: 500000000.0
# [IterativeImputer] Ending imputation round 39/100, elapsed time 0.90
# [IterativeImputer] Change: 784898023.8677473, scaled tolerance: 500000000.0
# [IterativeImputer] Ending imputation round 40/100, elapsed time 0.92
# [IterativeImputer] Change: 744421189.9103279, scaled tolerance: 500000000.0
# [IterativeImputer] Ending imputation round 41/100, elapsed time 0.94
# [IterativeImputer] Change: 706031720.5633535, scaled tolerance: 500000000.0
# [IterativeImputer] Ending imputation round 42/100, elapsed time 0.96
# [IterativeImputer] Change: 669621972.997469, scaled tolerance: 500000000.0
# [IterativeImputer] Ending imputation round 43/100, elapsed time 0.98
# [IterativeImputer] Change: 635089855.0829716, scaled tolerance: 500000000.0
# [IterativeImputer] Ending imputation round 44/100, elapsed time 1.00
# [IterativeImputer] Change: 602338539.2624264, scaled tolerance: 500000000.0
# [IterativeImputer] Ending imputation round 45/100, elapsed time 1.01
# [IterativeImputer] Change: 571276191.137022, scaled tolerance: 500000000.0
# [IterativeImputer] Ending imputation round 46/100, elapsed time 1.03
# [IterativeImputer] Change: 541815712.0235672, scaled tolerance: 500000000.0
# [IterativeImputer] Ending imputation round 47/100, elapsed time 1.05
# [IterativeImputer] Change: 513874494.76947594, scaled tolerance: 500000000.0
# [IterativeImputer] Ending imputation round 48/100, elapsed time 1.07
# [IterativeImputer] Change: 487374192.15276146, scaled tolerance: 500000000.0
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (3513, 6)
# [IterativeImputer] Ending imputation round 1/100, elapsed time 0.02
# [IterativeImputer] Change: 21869924337.313248, scaled tolerance: 72903000.0
# [IterativeImputer] Ending imputation round 2/100, elapsed time 0.04
# [IterativeImputer] Change: 8013428223.463564, scaled tolerance: 72903000.0
# [IterativeImputer] Ending imputation round 3/100, elapsed time 0.05
# [IterativeImputer] Change: 5861156070.790848, scaled tolerance: 72903000.0
# [IterativeImputer] Ending imputation round 4/100, elapsed time 0.07
# [IterativeImputer] Change: 4014690010.855051, scaled tolerance: 72903000.0
# [IterativeImputer] Ending imputation round 5/100, elapsed time 0.09
# [IterativeImputer] Change: 2568679631.9283895, scaled tolerance: 72903000.0
# [IterativeImputer] Ending imputation round 6/100, elapsed time 0.11
# [IterativeImputer] Change: 1685649433.3924074, scaled tolerance: 72903000.0
# [IterativeImputer] Ending imputation round 7/100, elapsed time 0.13
# [IterativeImputer] Change: 1162601832.8561077, scaled tolerance: 72903000.0
# [IterativeImputer] Ending imputation round 8/100, elapsed time 0.15
# [IterativeImputer] Change: 796726337.2229118, scaled tolerance: 72903000.0
# [IterativeImputer] Ending imputation round 9/100, elapsed time 0.16
# [IterativeImputer] Change: 622636781.8143721, scaled tolerance: 72903000.0
# [IterativeImputer] Ending imputation round 10/100, elapsed time 0.18
# [IterativeImputer] Change: 590464076.2070312, scaled tolerance: 72903000.0
# [IterativeImputer] Ending imputation round 11/100, elapsed time 0.20
# [IterativeImputer] Change: 563233759.5355368, scaled tolerance: 72903000.0
# [IterativeImputer] Ending imputation round 12/100, elapsed time 0.22
# [IterativeImputer] Change: 539041594.9934931, scaled tolerance: 72903000.0
# [IterativeImputer] Ending imputation round 13/100, elapsed time 0.24
# [IterativeImputer] Change: 516878620.14190197, scaled tolerance: 72903000.0
# [IterativeImputer] Ending imputation round 14/100, elapsed time 0.26
# [IterativeImputer] Change: 496191258.69505024, scaled tolerance: 72903000.0
# [IterativeImputer] Ending imputation round 15/100, elapsed time 0.27
# [IterativeImputer] Change: 476662412.4147787, scaled tolerance: 72903000.0
# [IterativeImputer] Ending imputation round 16/100, elapsed time 0.29
# [IterativeImputer] Change: 458100863.28275776, scaled tolerance: 72903000.0
# [IterativeImputer] Ending imputation round 17/100, elapsed time 0.31
# [IterativeImputer] Change: 440384400.8578062, scaled tolerance: 72903000.0
# [IterativeImputer] Ending imputation round 18/100, elapsed time 0.33
# [IterativeImputer] Change: 423429919.34782505, scaled tolerance: 72903000.0
# [IterativeImputer] Ending imputation round 19/100, elapsed time 0.33
# [IterativeImputer] Change: 407177274.1172695, scaled tolerance: 72903000.0
# [IterativeImputer] Ending imputation round 20/100, elapsed time 0.36
# [IterativeImputer] Change: 391580307.4906721, scaled tolerance: 72903000.0
# [IterativeImputer] Ending imputation round 21/100, elapsed time 0.38
# [IterativeImputer] Change: 376601705.91439724, scaled tolerance: 72903000.0
# [IterativeImputer] Ending imputation round 22/100, elapsed time 0.40
# [IterativeImputer] Change: 362209963.625803, scaled tolerance: 72903000.0
# [IterativeImputer] Ending imputation round 23/100, elapsed time 0.42
# [IterativeImputer] Change: 348377539.20808697, scaled tolerance: 72903000.0
# [IterativeImputer] Ending imputation round 24/100, elapsed time 0.43
# [IterativeImputer] Change: 335079707.5893307, scaled tolerance: 72903000.0
# [IterativeImputer] Ending imputation round 25/100, elapsed time 0.45
# [IterativeImputer] Change: 322293828.5101118, scaled tolerance: 72903000.0
# [IterativeImputer] Ending imputation round 26/100, elapsed time 0.47
# [IterativeImputer] Change: 309998870.3089695, scaled tolerance: 72903000.0
# [IterativeImputer] Ending imputation round 27/100, elapsed time 0.49
# [IterativeImputer] Change: 298175093.4754677, scaled tolerance: 72903000.0
# [IterativeImputer] Ending imputation round 28/100, elapsed time 0.50
# [IterativeImputer] Change: 286803835.7942858, scaled tolerance: 72903000.0
# [IterativeImputer] Ending imputation round 29/100, elapsed time 0.53
# [IterativeImputer] Change: 275867363.00769234, scaled tolerance: 72903000.0
# [IterativeImputer] Ending imputation round 30/100, elapsed time 0.54
# [IterativeImputer] Change: 265348762.26503658, scaled tolerance: 72903000.0
# [IterativeImputer] Ending imputation round 31/100, elapsed time 0.56
# [IterativeImputer] Change: 255231863.72760773, scaled tolerance: 72903000.0
# [IterativeImputer] Ending imputation round 32/100, elapsed time 0.58
# [IterativeImputer] Change: 245501181.01801968, scaled tolerance: 72903000.0
# [IterativeImputer] Ending imputation round 33/100, elapsed time 0.60
# [IterativeImputer] Change: 236141864.29851723, scaled tolerance: 72903000.0
# [IterativeImputer] Ending imputation round 34/100, elapsed time 0.61
# [IterativeImputer] Change: 227139662.0246868, scaled tolerance: 72903000.0
# [IterativeImputer] Ending imputation round 35/100, elapsed time 0.64
# [IterativeImputer] Change: 218480888.68903542, scaled tolerance: 72903000.0
# [IterativeImputer] Ending imputation round 36/100, elapsed time 0.67
# [IterativeImputer] Change: 210152396.84181786, scaled tolerance: 72903000.0
# [IterativeImputer] Ending imputation round 37/100, elapsed time 0.69
# [IterativeImputer] Change: 202141552.17218304, scaled tolerance: 72903000.0
# [IterativeImputer] Ending imputation round 38/100, elapsed time 0.71
# [IterativeImputer] Change: 194436210.89376354, scaled tolerance: 72903000.0
# [IterativeImputer] Ending imputation round 39/100, elapsed time 0.73
# [IterativeImputer] Change: 187024698.90712643, scaled tolerance: 72903000.0
# [IterativeImputer] Ending imputation round 40/100, elapsed time 0.75
# [IterativeImputer] Change: 179895792.3629961, scaled tolerance: 72903000.0
# [IterativeImputer] Ending imputation round 41/100, elapsed time 0.77
# [IterativeImputer] Change: 173038699.39962482, scaled tolerance: 72903000.0
# [IterativeImputer] Ending imputation round 42/100, elapsed time 0.79
# [IterativeImputer] Change: 166443042.84931946, scaled tolerance: 72903000.0
# [IterativeImputer] Ending imputation round 43/100, elapsed time 0.81
# [IterativeImputer] Change: 160098843.82015038, scaled tolerance: 72903000.0
# [IterativeImputer] Ending imputation round 44/100, elapsed time 0.82
# [IterativeImputer] Change: 153996506.02464676, scaled tolerance: 72903000.0
# [IterativeImputer] Ending imputation round 45/100, elapsed time 0.85
# [IterativeImputer] Change: 148126800.84102726, scaled tolerance: 72903000.0
# [IterativeImputer] Ending imputation round 46/100, elapsed time 0.87
# [IterativeImputer] Change: 142480852.9871664, scaled tolerance: 72903000.0
# [IterativeImputer] Ending imputation round 47/100, elapsed time 0.90
# [IterativeImputer] Change: 137050126.80593872, scaled tolerance: 72903000.0
# [IterativeImputer] Ending imputation round 48/100, elapsed time 0.92
# [IterativeImputer] Change: 131826413.13612843, scaled tolerance: 72903000.0
# [IterativeImputer] Ending imputation round 49/100, elapsed time 0.94
# [IterativeImputer] Change: 126801816.68097496, scaled tolerance: 72903000.0
# [IterativeImputer] Ending imputation round 50/100, elapsed time 0.95
# [IterativeImputer] Change: 121968743.90770721, scaled tolerance: 72903000.0
# [IterativeImputer] Ending imputation round 51/100, elapsed time 0.96
# [IterativeImputer] Change: 117319891.43316269, scaled tolerance: 72903000.0
# [IterativeImputer] Ending imputation round 52/100, elapsed time 0.97
# [IterativeImputer] Change: 112848234.84815598, scaled tolerance: 72903000.0
# [IterativeImputer] Ending imputation round 53/100, elapsed time 0.98
# [IterativeImputer] Change: 108547018.00742912, scaled tolerance: 72903000.0
# [IterativeImputer] Ending imputation round 54/100, elapsed time 0.99
# [IterativeImputer] Change: 104409742.72302055, scaled tolerance: 72903000.0
# [IterativeImputer] Ending imputation round 55/100, elapsed time 1.00
# [IterativeImputer] Change: 100430158.85832787, scaled tolerance: 72903000.0
# [IterativeImputer] Ending imputation round 56/100, elapsed time 1.02
# [IterativeImputer] Change: 96602254.834198, scaled tolerance: 72903000.0
# [IterativeImputer] Ending imputation round 57/100, elapsed time 1.03
# [IterativeImputer] Change: 92920248.47033119, scaled tolerance: 72903000.0
# [IterativeImputer] Ending imputation round 58/100, elapsed time 1.04
# [IterativeImputer] Change: 89378578.20234108, scaled tolerance: 72903000.0
# [IterativeImputer] Ending imputation round 59/100, elapsed time 1.05
# [IterativeImputer] Change: 85971894.6419754, scaled tolerance: 72903000.0
# [IterativeImputer] Ending imputation round 60/100, elapsed time 1.06
# [IterativeImputer] Change: 82695052.45376778, scaled tolerance: 72903000.0
# [IterativeImputer] Ending imputation round 61/100, elapsed time 1.09
# [IterativeImputer] Change: 79543102.55267143, scaled tolerance: 72903000.0
# [IterativeImputer] Ending imputation round 62/100, elapsed time 1.11
# [IterativeImputer] Change: 76511284.59161758, scaled tolerance: 72903000.0
# [IterativeImputer] Ending imputation round 63/100, elapsed time 1.14
# [IterativeImputer] Change: 73595019.76243591, scaled tolerance: 72903000.0
# [IterativeImputer] Ending imputation round 64/100, elapsed time 1.16
# [IterativeImputer] Change: 70789903.84585571, scaled tolerance: 72903000.0
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (3513, 6)
# [IterativeImputer] Ending imputation round 1/100, elapsed time 0.02
# [IterativeImputer] Change: 79191240784.44052, scaled tolerance: 480000000.0
# [IterativeImputer] Ending imputation round 2/100, elapsed time 0.05
# [IterativeImputer] Change: 51660368391.94967, scaled tolerance: 480000000.0
# [IterativeImputer] Ending imputation round 3/100, elapsed time 0.07
# [IterativeImputer] Change: 24127950423.531937, scaled tolerance: 480000000.0
# [IterativeImputer] Ending imputation round 4/100, elapsed time 0.09
# [IterativeImputer] Change: 19458706903.52335, scaled tolerance: 480000000.0
# [IterativeImputer] Ending imputation round 5/100, elapsed time 0.12
# [IterativeImputer] Change: 15882134292.820225, scaled tolerance: 480000000.0
# [IterativeImputer] Ending imputation round 6/100, elapsed time 0.15
# [IterativeImputer] Change: 13047367720.219963, scaled tolerance: 480000000.0
# [IterativeImputer] Ending imputation round 7/100, elapsed time 0.17
# [IterativeImputer] Change: 10756733494.757193, scaled tolerance: 480000000.0
# [IterativeImputer] Ending imputation round 8/100, elapsed time 0.20
# [IterativeImputer] Change: 8883420697.4459, scaled tolerance: 480000000.0
# [IterativeImputer] Ending imputation round 9/100, elapsed time 0.22
# [IterativeImputer] Change: 7342136764.037746, scaled tolerance: 480000000.0
# [IterativeImputer] Ending imputation round 10/100, elapsed time 0.24
# [IterativeImputer] Change: 6070457647.642179, scaled tolerance: 480000000.0
# [IterativeImputer] Ending imputation round 11/100, elapsed time 0.27
# [IterativeImputer] Change: 5019868921.534438, scaled tolerance: 480000000.0
# [IterativeImputer] Ending imputation round 12/100, elapsed time 0.29
# [IterativeImputer] Change: 4151419144.267267, scaled tolerance: 480000000.0
# [IterativeImputer] Ending imputation round 13/100, elapsed time 0.32
# [IterativeImputer] Change: 3433335476.8254385, scaled tolerance: 480000000.0
# [IterativeImputer] Ending imputation round 14/100, elapsed time 0.34
# [IterativeImputer] Change: 2839507950.812274, scaled tolerance: 480000000.0
# [IterativeImputer] Ending imputation round 15/100, elapsed time 0.35
# [IterativeImputer] Change: 2348406496.077352, scaled tolerance: 480000000.0
# [IterativeImputer] Ending imputation round 16/100, elapsed time 0.38
# [IterativeImputer] Change: 1942249376.4209518, scaled tolerance: 480000000.0
# [IterativeImputer] Ending imputation round 17/100, elapsed time 0.41
# [IterativeImputer] Change: 1606339745.2535288, scaled tolerance: 480000000.0
# [IterativeImputer] Ending imputation round 18/100, elapsed time 0.43
# [IterativeImputer] Change: 1328526243.4802182, scaled tolerance: 480000000.0
# [IterativeImputer] Ending imputation round 19/100, elapsed time 0.46
# [IterativeImputer] Change: 1098760477.6006224, scaled tolerance: 480000000.0
# [IterativeImputer] Ending imputation round 20/100, elapsed time 0.48
# [IterativeImputer] Change: 908732428.5610116, scaled tolerance: 480000000.0
# [IterativeImputer] Ending imputation round 21/100, elapsed time 0.50
# [IterativeImputer] Change: 751569462.289876, scaled tolerance: 480000000.0
# [IterativeImputer] Ending imputation round 22/100, elapsed time 0.53
# [IterativeImputer] Change: 621587609.3769503, scaled tolerance: 480000000.0
# [IterativeImputer] Ending imputation round 23/100, elapsed time 0.55
# [IterativeImputer] Change: 514085943.2304909, scaled tolerance: 480000000.0
# [IterativeImputer] Ending imputation round 24/100, elapsed time 0.58
# [IterativeImputer] Change: 425176551.4070637, scaled tolerance: 480000000.0
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (3513, 6)
# [IterativeImputer] Ending imputation round 1/100, elapsed time 0.02
# [IterativeImputer] Change: 21869924337.310684, scaled tolerance: 72903000.0
# [IterativeImputer] Ending imputation round 2/100, elapsed time 0.05
# [IterativeImputer] Change: 8013428223.4628315, scaled tolerance: 72903000.0
# [IterativeImputer] Ending imputation round 3/100, elapsed time 0.07
# [IterativeImputer] Change: 5861156070.788296, scaled tolerance: 72903000.0
# [IterativeImputer] Ending imputation round 4/100, elapsed time 0.10
# [IterativeImputer] Change: 4014690010.8554535, scaled tolerance: 72903000.0
# [IterativeImputer] Ending imputation round 5/100, elapsed time 0.12
# ...
# [IterativeImputer] Ending imputation round 1/2, elapsed time 0.00
# [IterativeImputer] Ending imputation round 2/2, elapsed time 0.00
# [IterativeImputer] Completing matrix with shape (3513, 6)
# [IterativeImputer] Ending imputation round 1/2, elapsed time 0.00
# [IterativeImputer] Ending imputation round 2/2, elapsed time 0.00
# [IterativeImputer] Completing matrix with shape (3513, 6)
# [IterativeImputer] Ending imputation round 1/2, elapsed time 0.00
# [IterativeImputer] Ending imputation round 2/2, elapsed time 0.00
# [IterativeImputer] Completing matrix with shape (3513, 6)
# [IterativeImputer] Ending imputation round 1/1, elapsed time 0.00
# [IterativeImputer] Completing matrix with shape (3513, 6)
# [IterativeImputer] Ending imputation round 1/23, elapsed time 0.00
# [IterativeImputer] Ending imputation round 2/23, elapsed time 0.00
# [IterativeImputer] Ending imputation round 3/23, elapsed time 0.02
# [IterativeImputer] Ending imputation round 4/23, elapsed time 0.02
# [IterativeImputer] Ending imputation round 5/23, elapsed time 0.02
# [IterativeImputer] Ending imputation round 6/23, elapsed time 0.03
# [IterativeImputer] Ending imputation round 7/23, elapsed time 0.03
# [IterativeImputer] Ending imputation round 8/23, elapsed time 0.03
# [IterativeImputer] Ending imputation round 9/23, elapsed time 0.03
# [IterativeImputer] Ending imputation round 10/23, elapsed time 0.04
# [IterativeImputer] Ending imputation round 11/23, elapsed time 0.04
# [IterativeImputer] Ending imputation round 12/23, elapsed time 0.04
# [IterativeImputer] Ending imputation round 13/23, elapsed time 0.04
# [IterativeImputer] Ending imputation round 14/23, elapsed time 0.04
# [IterativeImputer] Ending imputation round 15/23, elapsed time 0.05
# [IterativeImputer] Ending imputation round 16/23, elapsed time 0.05
# [IterativeImputer] Ending imputation round 17/23, elapsed time 0.05
# [IterativeImputer] Ending imputation round 18/23, elapsed time 0.06
# [IterativeImputer] Ending imputation round 19/23, elapsed time 0.06
# [IterativeImputer] Ending imputation round 20/23, elapsed time 0.06
# [IterativeImputer] Ending imputation round 21/23, elapsed time 0.06
# [IterativeImputer] Ending imputation round 22/23, elapsed time 0.06
# [IterativeImputer] Ending imputation round 23/23, elapsed time 0.06
# [IterativeImputer] Completing matrix with shape (3513, 6)
# [IterativeImputer] Ending imputation round 1/23, elapsed time 0.00
# [IterativeImputer] Ending imputation round 2/23, elapsed time 0.00
# [IterativeImputer] Ending imputation round 3/23, elapsed time 0.00
# [IterativeImputer] Ending imputation round 4/23, elapsed time 0.00
# [IterativeImputer] Ending imputation round 5/23, elapsed time 0.00
# [IterativeImputer] Ending imputation round 6/23, elapsed time 0.00
# [IterativeImputer] Ending imputation round 7/23, elapsed time 0.00
# [IterativeImputer] Ending imputation round 8/23, elapsed time 0.00
# [IterativeImputer] Ending imputation round 9/23, elapsed time 0.02
# [IterativeImputer] Ending imputation round 10/23, elapsed time 0.02
# [IterativeImputer] Ending imputation round 11/23, elapsed time 0.02
# [IterativeImputer] Ending imputation round 12/23, elapsed time 0.02
# [IterativeImputer] Ending imputation round 13/23, elapsed time 0.03
# [IterativeImputer] Ending imputation round 14/23, elapsed time 0.03
# [IterativeImputer] Ending imputation round 15/23, elapsed time 0.03
# [IterativeImputer] Ending imputation round 16/23, elapsed time 0.03
# [IterativeImputer] Ending imputation round 17/23, elapsed time 0.03
# [IterativeImputer] Ending imputation round 18/23, elapsed time 0.04
# [IterativeImputer] Ending imputation round 19/23, elapsed time 0.04
# [IterativeImputer] Ending imputation round 20/23, elapsed time 0.04
# [IterativeImputer] Ending imputation round 21/23, elapsed time 0.04
# [IterativeImputer] Ending imputation round 22/23, elapsed time 0.04
# [IterativeImputer] Ending imputation round 23/23, elapsed time 0.04
# [IterativeImputer] Completing matrix with shape (3513, 6)
# [IterativeImputer] Ending imputation round 1/6, elapsed time 0.00
# [IterativeImputer] Ending imputation round 2/6, elapsed time 0.00
# [IterativeImputer] Ending imputation round 3/6, elapsed time 0.00
# [IterativeImputer] Ending imputation round 4/6, elapsed time 0.00
# [IterativeImputer] Ending imputation round 5/6, elapsed time 0.00
# [IterativeImputer] Ending imputation round 6/6, elapsed time 0.01
# [IterativeImputer] Completing matrix with shape (3513, 6)
# [IterativeImputer] Ending imputation round 1/1, elapsed time 0.00
# [IterativeImputer] Completing matrix with shape (3513, 6)
# [IterativeImputer] Ending imputation round 1/3, elapsed time 0.00
# [IterativeImputer] Ending imputation round 2/3, elapsed time 0.00
# [IterativeImputer] Ending imputation round 3/3, elapsed time 0.00
# [IterativeImputer] Completing matrix with shape (3513, 6)
# [IterativeImputer] Ending imputation round 1/9, elapsed time 0.00
# [IterativeImputer] Ending imputation round 2/9, elapsed time 0.00
# [IterativeImputer] Ending imputation round 3/9, elapsed time 0.00
# [IterativeImputer] Ending imputation round 4/9, elapsed time 0.00
# [IterativeImputer] Ending imputation round 5/9, elapsed time 0.00
# [IterativeImputer] Ending imputation round 6/9, elapsed time 0.00
# [IterativeImputer] Ending imputation round 7/9, elapsed time 0.02
# [IterativeImputer] Ending imputation round 8/9, elapsed time 0.02
# [IterativeImputer] Ending imputation round 9/9, elapsed time 0.03
# [IterativeImputer] Completing matrix with shape (3513, 6)
# [IterativeImputer] Ending imputation round 1/9, elapsed time 0.00
# [IterativeImputer] Ending imputation round 2/9, elapsed time 0.01
# [IterativeImputer] Ending imputation round 3/9, elapsed time 0.01
# [IterativeImputer] Ending imputation round 4/9, elapsed time 0.02
# [IterativeImputer] Ending imputation round 5/9, elapsed time 0.02
# [IterativeImputer] Ending imputation round 6/9, elapsed time 0.02
# [IterativeImputer] Ending imputation round 7/9, elapsed time 0.02
# [IterativeImputer] Ending imputation round 8/9, elapsed time 0.03
# [IterativeImputer] Ending imputation round 9/9, elapsed time 0.03
# [IterativeImputer] Completing matrix with shape (3513, 6)
# [IterativeImputer] Ending imputation round 1/1, elapsed time 0.00
# [IterativeImputer] Completing matrix with shape (3513, 6)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.00
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.02
# [IterativeImputer] Ending imputation round 3/10, elapsed time 0.02
# [IterativeImputer] Ending imputation round 4/10, elapsed time 0.02
# [IterativeImputer] Ending imputation round 5/10, elapsed time 0.02
# [IterativeImputer] Ending imputation round 6/10, elapsed time 0.02
# [IterativeImputer] Ending imputation round 7/10, elapsed time 0.02
# [IterativeImputer] Ending imputation round 8/10, elapsed time 0.02
# [IterativeImputer] Ending imputation round 9/10, elapsed time 0.03
# [IterativeImputer] Ending imputation round 10/10, elapsed time 0.03
# [IterativeImputer] Completing matrix with shape (3513, 6)
# [IterativeImputer] Ending imputation round 1/9, elapsed time 0.00
# [IterativeImputer] Ending imputation round 2/9, elapsed time 0.00
# [IterativeImputer] Ending imputation round 3/9, elapsed time 0.00
# [IterativeImputer] Ending imputation round 4/9, elapsed time 0.00
# [IterativeImputer] Ending imputation round 5/9, elapsed time 0.02
# [IterativeImputer] Ending imputation round 6/9, elapsed time 0.02
# [IterativeImputer] Ending imputation round 7/9, elapsed time 0.02
# [IterativeImputer] Ending imputation round 8/9, elapsed time 0.02
# [IterativeImputer] Ending imputation round 9/9, elapsed time 0.02
# [IterativeImputer] Completing matrix with shape (3513, 6)
# [IterativeImputer] Ending imputation round 1/9, elapsed time 0.00
# [IterativeImputer] Ending imputation round 2/9, elapsed time 0.02
# [IterativeImputer] Ending imputation round 3/9, elapsed time 0.02
# [IterativeImputer] Ending imputation round 4/9, elapsed time 0.02
# [IterativeImputer] Ending imputation round 5/9, elapsed time 0.02
# [IterativeImputer] Ending imputation round 6/9, elapsed time 0.02
# [IterativeImputer] Ending imputation round 7/9, elapsed time 0.02
# [IterativeImputer] Ending imputation round 8/9, elapsed time 0.02
# [IterativeImputer] Ending imputation round 9/9, elapsed time 0.02
# [IterativeImputer] Completing matrix with shape (3513, 6)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.02
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.02
# [IterativeImputer] Ending imputation round 3/10, elapsed time 0.02
# [IterativeImputer] Ending imputation round 4/10, elapsed time 0.02
# [IterativeImputer] Ending imputation round 5/10, elapsed time 0.02
# [IterativeImputer] Ending imputation round 6/10, elapsed time 0.03
# [IterativeImputer] Ending imputation round 7/10, elapsed time 0.03
# [IterativeImputer] Ending imputation round 8/10, elapsed time 0.03
# [IterativeImputer] Ending imputation round 9/10, elapsed time 0.03
# [IterativeImputer] Ending imputation round 10/10, elapsed time 0.03
# [IterativeImputer] Completing matrix with shape (3513, 6)
# [IterativeImputer] Ending imputation round 1/9, elapsed time 0.00
# [IterativeImputer] Ending imputation round 2/9, elapsed time 0.00
# [IterativeImputer] Ending imputation round 3/9, elapsed time 0.00
# [IterativeImputer] Ending imputation round 4/9, elapsed time 0.00
# [IterativeImputer] Ending imputation round 5/9, elapsed time 0.00
# [IterativeImputer] Ending imputation round 6/9, elapsed time 0.00
# [IterativeImputer] Ending imputation round 7/9, elapsed time 0.01
# [IterativeImputer] Ending imputation round 8/9, elapsed time 0.01
# [IterativeImputer] Ending imputation round 9/9, elapsed time 0.01
# [IterativeImputer] Completing matrix with shape (3513, 6)
# [IterativeImputer] Ending imputation round 1/1, elapsed time 0.00
# [IterativeImputer] Completing matrix with shape (3513, 6)
# [IterativeImputer] Ending imputation round 1/11, elapsed time 0.01
# [IterativeImputer] Ending imputation round 2/11, elapsed time 0.01
# [IterativeImputer] Ending imputation round 3/11, elapsed time 0.01
# [IterativeImputer] Ending imputation round 4/11, elapsed time 0.01
# [IterativeImputer] Ending imputation round 5/11, elapsed time 0.01
# [IterativeImputer] Ending imputation round 6/11, elapsed time 0.02
# [IterativeImputer] Ending imputation round 7/11, elapsed time 0.02
# [IterativeImputer] Ending imputation round 8/11, elapsed time 0.02
# [IterativeImputer] Ending imputation round 9/11, elapsed time 0.02
# [IterativeImputer] Ending imputation round 10/11, elapsed time 0.02
# [IterativeImputer] Ending imputation round 11/11, elapsed time 0.02
# [IterativeImputer] Completing matrix with shape (3513, 6)
# [IterativeImputer] Ending imputation round 1/11, elapsed time 0.00
# [IterativeImputer] Ending imputation round 2/11, elapsed time 0.00
# [IterativeImputer] Ending imputation round 3/11, elapsed time 0.00
# [IterativeImputer] Ending imputation round 4/11, elapsed time 0.00
# [IterativeImputer] Ending imputation round 5/11, elapsed time 0.00
# [IterativeImputer] Ending imputation round 6/11, elapsed time 0.00
# [IterativeImputer] Ending imputation round 7/11, elapsed time 0.01
# [IterativeImputer] Ending imputation round 8/11, elapsed time 0.01
# [IterativeImputer] Ending imputation round 9/11, elapsed time 0.01
# [IterativeImputer] Ending imputation round 10/11, elapsed time 0.01
# [IterativeImputer] Ending imputation round 11/11, elapsed time 0.01
# [IterativeImputer] Completing matrix with shape (3513, 6)
# [IterativeImputer] Ending imputation round 1/11, elapsed time 0.00
# [IterativeImputer] Ending imputation round 2/11, elapsed time 0.00
# [IterativeImputer] Ending imputation round 3/11, elapsed time 0.00
# [IterativeImputer] Ending imputation round 4/11, elapsed time 0.00
# [IterativeImputer] Ending imputation round 5/11, elapsed time 0.00
# [IterativeImputer] Ending imputation round 6/11, elapsed time 0.00
# [IterativeImputer] Ending imputation round 7/11, elapsed time 0.00
# [IterativeImputer] Ending imputation round 8/11, elapsed time 0.00
# [IterativeImputer] Ending imputation round 9/11, elapsed time 0.00
# [IterativeImputer] Ending imputation round 10/11, elapsed time 0.00
# [IterativeImputer] Ending imputation round 11/11, elapsed time 0.00
# [IterativeImputer] Completing matrix with shape (3513, 6)
# [IterativeImputer] Ending imputation round 1/5, elapsed time 0.00
# [IterativeImputer] Ending imputation round 2/5, elapsed time 0.00
# [IterativeImputer] Ending imputation round 3/5, elapsed time 0.01
# [IterativeImputer] Ending imputation round 4/5, elapsed time 0.01
# [IterativeImputer] Ending imputation round 5/5, elapsed time 0.01
# [IterativeImputer] Completing matrix with shape (3513, 6)
# [IterativeImputer] Ending imputation round 1/6, elapsed time 0.00
# [IterativeImputer] Ending imputation round 2/6, elapsed time 0.00
# [IterativeImputer] Ending imputation round 3/6, elapsed time 0.00
# [IterativeImputer] Ending imputation round 4/6, elapsed time 0.00
# [IterativeImputer] Ending imputation round 5/6, elapsed time 0.01
# [IterativeImputer] Ending imputation round 6/6, elapsed time 0.01
# [IterativeImputer] Completing matrix with shape (3513, 6)
# [IterativeImputer] Ending imputation round 1/6, elapsed time 0.00
# [IterativeImputer] Ending imputation round 2/6, elapsed time 0.00
# [IterativeImputer] Ending imputation round 3/6, elapsed time 0.00
# [IterativeImputer] Ending imputation round 4/6, elapsed time 0.00
# [IterativeImputer] Ending imputation round 5/6, elapsed time 0.01
# [IterativeImputer] Ending imputation round 6/6, elapsed time 0.01
# [IterativeImputer] Completing matrix with shape (3513, 6)
# [IterativeImputer] Ending imputation round 1/2, elapsed time 0.00
# [IterativeImputer] Ending imputation round 2/2, elapsed time 0.00
# [IterativeImputer] Completing matrix with shape (3513, 6)
# [IterativeImputer] Ending imputation round 1/1, elapsed time 0.00
# [IterativeImputer] Completing matrix with shape (3513, 6)
# [IterativeImputer] Ending imputation round 1/8, elapsed time 0.00
# [IterativeImputer] Ending imputation round 2/8, elapsed time 0.00
# [IterativeImputer] Ending imputation round 3/8, elapsed time 0.00
# [IterativeImputer] Ending imputation round 4/8, elapsed time 0.00
# [IterativeImputer] Ending imputation round 5/8, elapsed time 0.00
# [IterativeImputer] Ending imputation round 6/8, elapsed time 0.01
# [IterativeImputer] Ending imputation round 7/8, elapsed time 0.01
# [IterativeImputer] Ending imputation round 8/8, elapsed time 0.01
# [IterativeImputer] Completing matrix with shape (3513, 6)
# [IterativeImputer] Ending imputation round 1/4, elapsed time 0.00
# [IterativeImputer] Ending imputation round 2/4, elapsed time 0.00
# [IterativeImputer] Ending imputation round 3/4, elapsed time 0.00
# [IterativeImputer] Ending imputation round 4/4, elapsed time 0.01
# [IterativeImputer] Completing matrix with shape (3513, 6)
# [IterativeImputer] Ending imputation round 1/4, elapsed time 0.00
# [IterativeImputer] Ending imputation round 2/4, elapsed time 0.00
# [IterativeImputer] Ending imputation round 3/4, elapsed time 0.00
# [IterativeImputer] Ending imputation round 4/4, elapsed time 0.01
# [IterativeImputer] Completing matrix with shape (3513, 6)
# [IterativeImputer] Ending imputation round 1/5, elapsed time 0.00
# [IterativeImputer] Ending imputation round 2/5, elapsed time 0.00
# [IterativeImputer] Ending imputation round 3/5, elapsed time 0.00
# [IterativeImputer] Ending imputation round 4/5, elapsed time 0.00
# [IterativeImputer] Ending imputation round 5/5, elapsed time 0.00
# [IterativeImputer] Completing matrix with shape (3513, 6)
# [IterativeImputer] Ending imputation round 1/1, elapsed time 0.00
# C:\Users\Riya\AppData\Local\Temp\ipykernel_16488\378415395.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X_train['Sector'] = sector_train.reset_index(drop=True)
# "sector_test= X_test['Sector']\nX_test = pipeline.transform(X_test.drop('Sector',axis=1))\nX_test['Sector'] = sector_test.reset_index(drop=True)"

# %%
# Out:
# Pipeline(steps=[('drop_missing', DropHighMissingColumns()),
#                 ('missing_imputation',
#                  CorrelationBasedIterativeImputer(max_iter=100))])

# %%
sns.pairplot(df.drop('Sector',axis=1))
plt.show()
